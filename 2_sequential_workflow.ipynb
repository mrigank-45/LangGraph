# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
# Out:
# /Users/mriganksmacbook/Coding/AI/LangGraph/venv/lib/python3.14/site-packages/langchain_core/_api/deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from langchain_groq import ChatGroq  
from dotenv import load_dotenv
load_dotenv()

model = ChatGroq(model='llama-3.3-70b-versatile', temperature=0)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* Importance of AI in India\'s economic growth and development\n* Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and increasing demand for AI-powered solutions.\n\n**II. Current State of AI in India**\n\n* Overview of India\'s AI landscape, including key players, startups, and research institutions\n* Discussion of the current AI ecosystem in India, including challenges and opportunities\n* Statistics on AI adoption in India, including the number of AI startups, funding, and job creation\n\n**III. Government Initiatives and Policies**\n\n* Overview of the Indian government\'s initiatives to promote AI adoption, including:\n\t+ National AI Strategy\n\t+ AI Task Force\n\t+ AI-related policies and regulations\n* Discussion of the impact of these initiatives on the growth of AI in India\n* Examples of government-funded AI projects and initiatives\n\n**IV. Key Sectors Driving AI Adoption in India**\n\n* Discussion of the key sectors driving AI adoption in India, including:\n\t+ Healthcare\n\t+ Finance and Banking\n\t+ Education\n\t+ Manufacturing and Logistics\n\t+ Transportation\n* Examples of AI-powered solutions and innovations in each sector\n* Statistics on the growth of AI adoption in each sector\n\n**V. Technological Advancements and Innovations**\n\n* Overview of the technological advancements driving AI adoption in India, including:\n\t+ Machine Learning (ML)\n\t+ Natural Language Processing (NLP)\n\t+ Computer Vision\n\t+ Robotics\n* Discussion of the innovations and breakthroughs in AI research and development in India\n* Examples of AI-powered products and services developed in India\n\n**VI. Challenges and Limitations**\n\n* Discussion of the challenges and limitations facing AI adoption in India, including:\n\t+ Data quality and availability\n\t+ Talent and skills gap\n\t+ Infrastructure and funding constraints\n\t+ Regulatory and policy challenges\n* Examples of how these challenges are being addressed by the government, industry, and academia\n\n**VII. Future Outlook and Opportunities**\n\n* Discussion of the future outlook for AI in India, including:\n\t+ Emerging trends and technologies\n\t+ Growing demand for AI-powered solutions\n\t+ Increasing investment in AI research and development\n* Examples of the opportunities and potential applications of AI in India, including:\n\t+ Job creation and skill development\n\t+ Economic growth and development\n\t+ Social impact and improvement of public services\n\n**VIII. Conclusion**\n\n* Summary of the key points and takeaways from the blog\n* Final thoughts on the rise of AI in India and its potential to drive economic growth, innovation, and social impact\n* Call to action for readers to learn more about AI and its applications in India.\n\nThis outline should provide a comprehensive framework for a blog on the topic "Rise of AI in India". You can expand or modify it as needed to suit your specific needs and goals.', 'content': '**The Rise of AI in India: A New Era of Innovation and Growth**\n\n**Introduction**\n\nArtificial Intelligence (AI) has been transforming the world at an unprecedented pace, and India is no exception. With its growing importance globally, AI has become a crucial factor in India\'s economic growth and development. The Indian government, startups, and research institutions are working together to harness the power of AI, driving innovation and growth in various sectors. In this blog, we will explore the rise of AI in India, its current state, government initiatives, key sectors driving adoption, technological advancements, challenges, and future outlook.\n\n**Current State of AI in India**\n\nIndia\'s AI landscape is rapidly evolving, ...

# %%
print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance globally
# * Importance of AI in India's economic growth and development
# * Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and increasing demand for AI-powered solutions.
#
# **II. Current State of AI in India**
#
# * Overview of India's AI landscape, including key players, startups, and research institutions
# * Discussion of the current AI ecosystem in India, including challenges and opportunities
# * Statistics on AI adoption in India, including the number of AI startups, funding, and job creation
#
# **III. Government Initiatives and Policies**
#
# * Overview of the Indian government's initiatives to promote AI adoption, including:
# 	+ National AI Strategy
# 	+ AI Task Force
# 	+ AI-related policies and regulations
# * Discussion of the impact of these initiatives on the growth of AI in India
# * Examples of government-funded AI projects and initiatives
#
# **IV. Key Sectors Driving AI Adoption in India**
#
# * Discussion of the key sectors driving AI adoption in India, including:
# 	+ Healthcare
# 	+ Finance and Banking
# 	+ Education
# 	+ Manufacturing and Logistics
# 	+ Transportation
# * Examples of AI-powered solutions and innovations in each sector
# * Statistics on the growth of AI adoption in each sector
#
# **V. Technological Advancements and Innovations**
#
# * Overview of the technological advancements driving AI adoption in India, including:
# 	+ Machine Learning (ML)
# 	+ Natural Language Processing (NLP)
# 	+ Computer Vision
# 	+ Robotics
# * Discussion of the innovations and breakthroughs in AI research and development in India
# * Examples of AI-powered products and services developed in India
#
# **VI. Challenges and Limitations**
#
# * Discussion of the challenges and limitations facing AI adoption in India, including:
# 	+ Data quality and availability
# 	+ Talent and skills gap
# 	+ Infrastructure and funding constraints
# 	+ Regulatory and policy challenges
# * Examples of how these challenges are being addressed by the government, industry, and academia
#
# **VII. Future Outlook and Opportunities**
#
# * Discussion of the future outlook for AI in India, including:
# 	+ Emerging trends and technologies
# 	+ Growing demand for AI-powered solutions
# 	+ Increasing investment in AI research and development
# * Examples of the opportunities and potential applications of AI in India, including:
# 	+ Job creation and skill development
# 	+ Economic growth and development
# 	+ Social impact and improvement of public services
#
# **VIII. Conclusion**
#
# * Summary of the key points and takeaways from the blog
# * Final thoughts on the rise of AI in India and its potential to drive economic growth, innovation, and social impact
# * Call to action for readers to learn more about AI and its applications in India.
#
# This outline should provide a comprehensive framework for a blog on the topic "Rise of AI in India". You can expand or modify it as needed to suit your specific needs and goals.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: A New Era of Innovation and Growth**
#
# **Introduction**
#
# Artificial Intelligence (AI) has been transforming the world at an unprecedented pace, and India is no exception. With its growing importance globally, AI has become a crucial factor in India's economic growth and development. The Indian government, startups, and research institutions are working together to harness the power of AI, driving innovation and growth in various sectors. In this blog, we will explore the rise of AI in India, its current state, government initiatives, key sectors driving adoption, technological advancements, challenges, and future outlook.
#
# **Current State of AI in India**
#
# India's AI landscape is rapidly evolving, with key players, startups, and research institutions making significant contributions. The current AI ecosystem in India is characterized by a mix of challenges and opportunities. According to a report by NASSCOM, the number of AI startups in India has grown from 100 in 2015 to over 500 in 2022. The AI market in India is expected to reach $7.8 billion by 2025, growing at a CAGR of 30.8%. The Indian government has also launched several initiatives to promote AI adoption, including the establishment of the National AI Strategy and the AI Task Force.
#
# Some notable statistics on AI adoption in India include:
#
# * Over 50% of Indian companies have already adopted AI-powered solutions.
# * The AI market in India is expected to create over 100,000 new jobs by 2025.
# * India has seen a significant increase in AI-related funding, with over $1 billion invested in AI startups in 2022 alone.
#
# **Government Initiatives and Policies**
#
# The Indian government has been actively promoting AI adoption through various initiatives and policies. The National AI Strategy, launched in 2018, aims to make India a global leader in AI by 2025. The AI Task Force, established in 2017, is responsible for developing a comprehensive AI strategy for the country. The government has also launched several AI-related policies and regulations, including the Data Protection Bill and the National Digital Communications Policy.
#
# Some examples of government-funded AI projects and initiatives include:
#
# * The establishment of the Centre for Artificial Intelligence and Robotics (CAIR) at the Indian Institute of Science (IISc).
# * The launch of the AI-powered chatbot, "MyGov", to provide citizen-centric services.
# * The development of an AI-powered platform for healthcare, "eSanjeevani", to provide telemedicine services.
#
# **Key Sectors Driving AI Adoption in India**
#
# Several key sectors are driving AI adoption in India, including:
#
# * **Healthcare**: AI-powered solutions are being used to improve patient outcomes, streamline clinical workflows, and enhance patient engagement. For example, the Indian government has launched an AI-powered platform for healthcare, "eSanjeevani", to provide telemedicine services.
# * **Finance and Banking**: AI-powered solutions are being used to improve customer service, detect fraud, and enhance risk management. For example, several Indian banks have launched AI-powered chatbots to provide customer support.
# * **Education**: AI-powered solutions are being used to improve student outcomes, enhance teacher productivity, and personalize learning experiences. For example, the Indian government has launched an AI-powered platform for education, "DIKSHA", to provide personalized learning experiences.
# * **Manufacturing and Logistics**: AI-powered solutions are being used to improve supply chain management, enhance quality control, and optimize production processes. For example, several Indian manufacturing companies have adopted AI-powered solutions to improve their supply chain management.
# * **Transportation**: AI-powered solutions are being used to improve traffic management, enhance safety, and optimize route planning. For example, the Indian government has launched an AI-powered platform for traffic management, "Smart Traffic Management System", to improve traffic flow and reduce congestion.
#
# Some notable statistics on the growth of AI adoption in each sector include:
#
# * The healthcare sector is expected to see a growth of 40% in AI adoption by 2025.
# * The finance and banking sector is expected to see a growth of 30% in AI adoption by 2025.
# * The education sector is expected to see a growth of 25% in AI adoption by 2025.
#
# **Technological Advancements and Innovations**
#
# Several technological advancements are driving AI adoption in India, including:
#
# * **Machine Learning (ML)**: ML algorithms are being used to develop AI-powered solutions for various industries.
# * **Natural Language Processing (NLP)**: NLP is being used to develop AI-powered chatbots and virtual assistants.
# * **Computer Vision**: Computer vision is being used to develop AI-powered solutions for image and video analysis.
# * **Robotics**: Robotics is being used to develop AI-powered solutions for manufacturing, logistics, and healthcare.
#
# Some examples of AI-powered products and services developed in India include:
#
# * The AI-powered chatbot, "MyGov", developed by the Indian government to provide citizen-centric services.
# * The AI-powered platform for healthcare, "eSanjeevani", developed by the Indian government to provide telemedicine services.
# * The AI-powered platform for education, "DIKSHA", developed by the Indian government to provide personalized learning experiences.
#
# **Challenges and Limitations**
#
# Despite the growth of AI in India, there are several challenges and limitations that need to be addressed, including:
#
# * **Data quality and availability**: The lack of high-quality data is a significant challenge for AI adoption in India.
# * **Talent and skills gap**: The shortage of skilled professionals is a significant challenge for AI adoption in India.
# * **Infrastructure and funding constraints**: The lack of infrastructure and funding is a significant challenge for AI adoption in India.
# * **Regulatory and policy challenges**: The lack of clear regulations and policies is a significant challenge for AI adoption in India.
#
# Some examples of how these challenges are being addressed include:
#
# * The Indian government has launched several initiatives to improve data quality and availability, including the establishment of the National Data Repository.
# * The Indian government has launched several initiatives to address the talent and skills gap, including the establishment of the National Skill Development Corporation.
# * The Indian government has launched several initiatives to improve infrastructure and funding, including the establishment of the Digital India initiative.
#
# **Future Outlook and Opportunities**
#
# The future outlook for AI in India is promising, with several emerging trends and technologies expected to drive growth and innovation. Some of the emerging trends and technologies include:
#
# * **Edge AI**: Edge AI is expected to play a significant role in the growth of AI in India, with several companies already adopting edge AI solutions.
# * **Explainable AI**: Explainable AI is expected to play a significant role in the growth of AI in India, with several companies already adopting explainable AI solutions.
# * **AI for social good**: AI for social good is expected to play a significant role in the growth of AI in India, with several companies already adopting AI-powered solutions for social good.
#
# Some examples of the opportunities and potential applications of AI in India include:
#
# * **Job creation and skill development**: AI is expected to create over 100,000 new jobs in India by 2025.
# * **Economic growth and development**: AI is expected to contribute significantly to India's economic growth and development, with the AI market in India expected to reach $7.8 billion by 2025.
# * **Social impact and improvement of public services**: AI is expected to have a significant social impact in India, with several AI-powered solutions already being used to improve public services.
#
# **Conclusion**
#
# In conclusion, the rise of AI in India is a significant trend that is expected to drive innovation, growth, and social impact in the country. With the government, startups, and research institutions working together to harness the power of AI, India is poised to become a global leader in AI. However, there are several challenges and limitations that need to be addressed, including data quality and availability, talent and skills gap, infrastructure and funding constraints, and regulatory and policy challenges. As AI continues to evolve and grow in India, it is essential to address these challenges and ensure that the benefits of AI are equitably distributed across the country.
#
# **Call to Action**
#
# We urge readers to learn more about AI and its applications in India, and to explore the opportunities and potential of AI in driving economic growth, innovation, and social impact. Whether you are a student, a professional, or an entrepreneur, AI has the potential to transform your life and career. So, let us embark on this exciting journey of AI adoption in India, and work together to create a brighter future for ourselves and for the country.
